# %% [markdown]
# # #1 Inspect the Dataset

# %% [markdown]
# Read the dataset with pandas and show the early of the sample data

# %%
import pandas as pd

df = pd.read_csv('data/Life Expectancy Data.csv')

df
# Out:
#           Country  Year      Status  Life expectancy   Adult Mortality  \
# 0     Afghanistan  2015  Developing              65.0            263.0
# 1     Afghanistan  2014  Developing              59.9            271.0
# 2     Afghanistan  2013  Developing              59.9            268.0
# 3     Afghanistan  2012  Developing              59.5            272.0
# 4     Afghanistan  2011  Developing              59.2            275.0
# ...           ...   ...         ...               ...              ...
# 2933     Zimbabwe  2004  Developing              44.3            723.0
# 2934     Zimbabwe  2003  Developing              44.5            715.0
# 2935     Zimbabwe  2002  Developing              44.8             73.0
# 2936     Zimbabwe  2001  Developing              45.3            686.0
# 2937     Zimbabwe  2000  Developing              46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0                62     0.01               71.279624         65.0      1154
# 1                64     0.01               73.523582         62.0       492
# 2                66     0.01               73.219243         64.0       430
# 3                69     0.01               78.184215         67.0      2787
# 4                71     0.01                7.097109         68.0      3013
# ...             ...      ...                     ...          ...       ...
# 2933             27     4.36                0.000000         68.0        31
# 2934             26     4.06                0.000000          7.0       998
# 2935             25     4.43                0.000000         73.0       304
# 2936             25     1.72                0.000000         76.0       529
# 2937             24     1.68                0.000000         79.0      1483
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  \
# 0     ...    6.0               8.16         65.0        0.1  584.259210
# 1     ...   58.0               8.18         62.0        0.1  612.696514
# 2     ...   62.0               8.13         64.0        0.1  631.744976
# 3     ...   67.0               8.52         67.0        0.1  669.959000
# 4     ...   68.0               7.87         68.0        0.1   63.537231
# ...   ...    ...                ...          ...        ...         ...
# 2933  ...   67.0               7.13         65.0       33.6  454.366654
# 2934  ...    7.0               6.52         68.0       36.7  453.351155
# 2935  ...   73.0               6.53         71.0       39.8   57.348340
# 2936  ...   76.0               6.16         75.0       42.1  548.587312
# 2937  ...   78.0               7.10         78.0       43.5  547.358878
#
#       Population   thinness  1-19 years   thinness 5-9 years  \
# 0     33736494.0                   17.2                 17.3
# 1       327582.0                   17.5                 17.5
# 2     31731688.0                   17.7                 17.7
# 3      3696958.0                   17.9                 18.0
# 4      2978599.0                   18.2                 18.2
# ...          ...                    ...                  ...
# 2933  12777511.0                    9.4                  9.4
# 2934  12633897.0                    9.8                  9.9
# 2935    125525.0                    1.2                  1.3
# 2936  12366165.0                    1.6                  1.7
# 2937  12222251.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
df = df[df['Country'] == 'Indonesia']

df
# Out:
#         Country  Year      Status  Life expectancy   Adult Mortality  \
# 1202  Indonesia  2015  Developing              69.1            176.0
# 1203  Indonesia  2014  Developing              68.9            179.0
# 1204  Indonesia  2013  Developing              68.7            181.0
# 1205  Indonesia  2012  Developing              68.5            183.0
# 1206  Indonesia  2011  Developing              68.3            185.0
# 1207  Indonesia  2010  Developing              68.1            187.0
# 1208  Indonesia  2009  Developing              67.9            189.0
# 1209  Indonesia  2008  Developing              67.7            189.0
# 1210  Indonesia  2007  Developing              67.5             19.0
# 1211  Indonesia  2006  Developing              67.3            191.0
# 1212  Indonesia  2005  Developing              67.2             19.0
# 1213  Indonesia  2004  Developing              65.3            213.0
# 1214  Indonesia  2003  Developing              66.9            189.0
# 1215  Indonesia  2002  Developing              66.7            189.0
# 1216  Indonesia  2001  Developing              66.5            188.0
# 1217  Indonesia  2000  Developing              66.3            188.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 1202            114      NaN                0.000000         78.0     15099
# 1203            119     0.09              200.068444         78.0     12943
# 1204            124     0.09               22.847831         85.0      8419
# 1205            129     0.08              254.468826         83.0     15489
# 1206            134     0.08              211.878340         81.0     21893
# 1207            138     0.08              190.545365         83.0     18869
# 1208            143     0.08              125.798068         82.0     20818
# 1209            149     0.07               10.263411         82.0     15369
# 1210            154     0.06              102.633435         76.0     19456
# 1211            159     0.06               72.015932         66.0     20422
# 1212            163     0.06                5.381783         65.0     15853
# 1213            174     0.06               55.361072         64.0     29171
# 1214            173     0.05                8.460156         64.0     24457
# 1215            177     0.05               43.178673         63.0     14492
# 1216            182     0.06               33.958371         62.0      3825
# 1217            187     0.06                3.433344         65.0      3344
#
#       ...  Polio  Total expenditure  Diphtheria    HIV/AIDS          GDP  \
# 1202  ...    8.0                NaN         78.0        0.3  3336.166860
# 1203  ...    8.0               2.85         78.0        0.3  3491.595887
# 1204  ...   86.0               2.93         85.0        0.3   362.663981
# 1205  ...   84.0               2.90         83.0        0.3  3687.953996
# 1206  ...   81.0               2.71         81.0        0.3  3634.276850
# 1207  ...   82.0               2.74         81.0        0.3  3113.486350
# 1208  ...   85.0               2.83         78.0        0.3  2254.445660
# 1209  ...   83.0               2.81         77.0        0.2   216.527660
# 1210  ...   77.0               3.10         73.0        0.2  1855.939150
# 1211  ...   78.0               2.91         72.0        0.1  1586.254000
# 1212  ...   79.0               2.79         72.0        0.1   126.928834
# 1213  ...   79.0               2.37         71.0        0.1  1148.569960
# 1214  ...    8.0               2.53         71.0        0.1   164.594470
# 1215  ...    8.0               2.27          7.0        0.1   899.555686
# 1216  ...   77.0               2.23         76.0        0.1   747.981745
# 1217  ...   72.0               1.98         75.0        0.1    78.927440
#
#        Population   thinness  1-19 years   thinness 5-9 years  \
# 1202  258162113.0                    1.4                  1.2
# 1203  255131116.0                    1.4                  1.2
# 1204   25232263.0                    1.5                  1.3
# 1205  248883232.0                    1.5                  1.4
# 1206   24577511.0                    1.6                  1.5
# 1207  242524123.0                    1.6                  1.5
# 1208   23934478.0                    1.7                  1.6
# 1209  236159276.0                    1.7                  1.7
# 1210  232989141.0                    1.8                  1.7
# 1211   22983822.0                    1.8                  1.8
# 1212   22671273.0                    1.9                  1.9
# 1213  223614649.0                    1.9                  1.9
# 1214   22545214.0                    1.9                 11.0
# 1215    2175859.0                   11.0                 11.1
# 1216    2145652.0                   11.0                 11.1
# 1217   21154429.0                   11.0                 11.2
#
#       Income composition of resources  Schooling
# 1202                            0.686       12.9
# 1203                            0.682       12.9
# 1204                            0.677       12.9
# 1205                            0.669       12.6
# 1206                            0.662       12.3
# 1207                            0.656       12.1
# 1208                            0.645       11.7
# 1209                            0.641       11.7
# 1210                            0.638       11.0
# 1211                            0.632       10.9
# 1212                            0.629       11.1
# 1213                            0.624       11.0
# 1214                            0.613       10.8
# 1215                            0.608       10.6
# 1216                            0.604       10.6
# 1217                            0.597       10.7
#
# [16 rows x 22 columns]

# %% [markdown]
# To select the **TV**, drop the other media like the **Radio** and the **Newspaper**

# %%
df_year = df.iloc[:, 1]

# %%
df_life = df.iloc[:, 3]

# %%
data = {"years": df_year,
        "life": df_life}

# %%
df = pd.concat(data, axis = 1)
df
# Out:
#       years  life
# 1202   2015  69.1
# 1203   2014  68.9
# 1204   2013  68.7
# 1205   2012  68.5
# 1206   2011  68.3
# 1207   2010  68.1
# 1208   2009  67.9
# 1209   2008  67.7
# 1210   2007  67.5
# 1211   2006  67.3
# 1212   2005  67.2
# 1213   2004  65.3
# 1214   2003  66.9
# 1215   2002  66.7
# 1216   2001  66.5
# 1217   2000  66.3

# %% [markdown]
# The dimension of the datasets

# %%
df.shape
# Out:
# (16, 2)

# %%
df.info
# Out:
# <bound method DataFrame.info of       years  life
# 1202   2015  69.1
# 1203   2014  68.9
# 1204   2013  68.7
# 1205   2012  68.5
# 1206   2011  68.3
# 1207   2010  68.1
# 1208   2009  67.9
# 1209   2008  67.7
# 1210   2007  67.5
# 1211   2006  67.3
# 1212   2005  67.2
# 1213   2004  65.3
# 1214   2003  66.9
# 1215   2002  66.7
# 1216   2001  66.5
# 1217   2000  66.3>

# %% [markdown]
# Is there is a null dataset?

# %%
df.isnull().sum()
# Out:
# years    0
# life     0
# dtype: int64

# %% [markdown]
# # #2 Dataset understanding using Exploratory Data Analysis (EDA)

# %% [markdown]
# EDA techniques can be divided into two types:
# + Numerical techniques
# + Graphical techniques

# %% [markdown]
# ## Analyze the relationship between the predictor and the target variable
#
# For this, we can use the following techniques:
#
# + The scatterplot
# + [Pearson correlation coefficient](https://www.wallstreetmojo.com/pearson-correlation-coefficient/)
#
# **The scatterplot** is used to visualize the relationship between the predictor and the target variable. If there is a relationship between the variables, we can look for the following characteristics:
#
# + **Overall pattern:** This can be a linear pattern, a curvy pattern or an exponential pattern, etc.
# + **Strength:** This refers to how closely the points arrange.
# + **Direction:** This can be either positive or negative. Positive means that when the predictor variable increases, the response variable also increases. Negative means that when the predictor variable increases, the response variable decreases and vice versa.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')

fig, ax = plt.subplots(figsize=(9, 6))

sns.scatterplot(x='years', y = 'life', data=df, ax=ax, color='red')

ax.set_title('The relationship between TV advertising and sales', pad=20, size=18, color='gray')

plt.savefig('img_output/id_life_scaterplot.png')

# %% [markdown]
# **The Pearson correlation** coefficient measures the strength of a linear relationship between two numerical variables. If the relationship is not linear, the correlation coefficient could be misleading.

# %%
df.corr(method='pearson')
# Out:
#           years      life
# years  1.000000  0.914684
# life   0.914684  1.000000

# %%
# %matplotlib inline

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize=(14, 5.4))
plt.tight_layout(pad=5)

sns.distplot(df['years'], ax=ax[0])
ax[0].axvline(x=np.mean(df['years']), color='red', label='mean')
ax[0].axvline(x=np.median(df['years']), color='orange', label='median')
ax[0].set_ylabel('Frequency')
ax[0].set_title('Histogram of TV')
ax[0].legend(loc='upper right')

sns.distplot(df['life'], ax=ax[1])
ax[1].axvline(x=np.mean(df['life']), color='red', label='mean')
ax[1].axvline(x=np.median(df['life']), color='orange', label='median')
ax[1].set_ylabel('Frequency')
ax[1].set_title('Histogram of Sales')
ax[1].legend(loc='upper right')

plt.savefig('img_output/id_life_histogram.png', dpi=100)
# Out:
# c:\users\rohman\documents\pyenvironment\python-3.7.9-all-packages\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\rohman\documents\pyenvironment\python-3.7.9-all-packages\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.describe().T
# Out:
#        count        mean       std     min      25%     50%      75%     max
# years   16.0  2007.50000  4.760952  2000.0  2003.75  2007.5  2011.25  2015.0
# life    16.0    67.55625  1.049424    65.3    66.85    67.6    68.35    69.1

# %% [markdown]
# Now, we create boxplots. A boxplot provides a graphical representation of 5-Number Summary — MINIMUM, Q1, Median, Q3 and MAXIMUM.

# %%
# %matplotlib inline

import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('ggplot')

fig, ax = plt.subplots(nrows=2, ncols=1, figsize=(9, 7))
plt.tight_layout(pad=5)

sns.boxplot(x=df['years'], ax=ax[0], color='orange')
sns.boxplot(x=df['life'], ax=ax[1])

plt.savefig('img_output/id_life_boxplots.png')
